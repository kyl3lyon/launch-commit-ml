# %%
import os
os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-11-openjdk-amd64'
os.environ['PATH'] = f"{os.environ['JAVA_HOME']}/bin:{os.environ['PATH']}"

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from datetime import datetime, timedelta

# %%
def create_spark_session():
    return SparkSession.builder \
        .appName("FieldMillDataProcessing") \
        .config("spark.driver.memory", "4g") \
        .config("spark.executor.memory", "4g") \
        .config("spark.sql.session.timeZone", "UTC") \
        .getOrCreate()

# %%
def process_file(spark, file_path):
    try:
        # Read the file content
        with open(file_path, 'r') as file:
            lines = file.readlines()
        
        # Parse the base date and time from the header
        date_time = datetime.strptime(lines[0].strip(), "%m/%d/%Y %H:%M")
        base_hour = date_time.hour
        base_date = date_time.date()
        print(f"Base date and time: {date_time}")
        
        # Process the data lines
        data = []
        for line in lines[1:]:
            parts = line.strip().split(',')
            if len(parts) >= 4:
                try:
                    hour_index = int(parts[0])
                    minute = int(parts[1])
                    second = int(parts[2])
                    electric_field = float(parts[3])
                    
                    # Calculate the actual hour
                    actual_hour = base_hour + (hour_index - 1)
                    
                    # Handle day rollover if hour exceeds 23
                    timestamp = datetime.combine(base_date, time(0, 0, 0)) + timedelta(
                        hours=actual_hour, minutes=minute, seconds=second
                    )
                    
                    data.append((timestamp, electric_field))
                except ValueError as ve:
                    print(f"Skipping line due to ValueError: {line.strip()} - {ve}")
            else:
                print(f"Skipping line due to insufficient data: {line.strip()}")
        
        if not data:
            print(f"No valid data in file {file_path}")
            return None
    
        # Create a DataFrame from the processed data
        df = spark.createDataFrame(data, ["DATETIME", "ELECTRIC_FIELD"])
        
        return df
    except Exception as e:
        print(f"Error processing file {file_path}: {str(e)}")
        import traceback
        traceback.print_exc()
        return None

# %%
def process_month(spark, year, month):
    base_path = f"data/transformed/field_mill_50hz/{year}/{month:02d}"
    
    if not os.path.exists(base_path):
        print(f"No data found for {year}-{month:02d}")
        return None
    
    all_data = []
    total_files = 0
    processed_files = 0

    for day in sorted(os.listdir(base_path)):
        day_path = os.path.join(base_path, day)
        for hour_folder in sorted(os.listdir(day_path)):
            file_path = os.path.join(day_path, hour_folder, f"{hour_folder}.txt")
            total_files += 1
            df = process_file(spark, file_path)
            if df is not None:
                all_data.append(df)
                processed_files += 1
                print(f"Completed processing file: {file_path}")

    if not all_data:
        print(f"No data was successfully processed for {year}-{month:02d}")
        return None

    print(f"\nProcessed {processed_files} out of {total_files} files for {year}-{month:02d}.")

    monthly_df = all_data[0]
    for df in all_data[1:]:
        monthly_df = monthly_df.union(df)
    
    monthly_df = monthly_df.sort("DATETIME")
    
    return monthly_df

# %%
def process_year(spark, year):
    # Create the process folder if it doesn't exist
    os.makedirs(f"data/process/field_mill_data_{year}", exist_ok=True)
    
    for month in range(1, 13):
        monthly_df = process_month(spark, year, month)
        if monthly_df is not None:
            # Save the DataFrame for this month
            output_path = f"data/process/field_mill_data_{year}/month_{month:02d}"
            monthly_df.write.csv(output_path, header=True, mode="overwrite")
            print(f"Data for {year}-{month:02d} has been processed and saved to {output_path}")
        else:
            print(f"Skipping {year}-{month:02d} due to no data")
        
        # Clear cache to free up memory
        spark.catalog.clearCache()

    print(f"Processing complete for year {year}")

# %%
# Create Spark session
spark = create_spark_session()

# Process the data for 1996
process_year(spark, 1996)

# Stop the Spark session
spark.stop()
# Out:
# No data found for 1996-01
# Skipping 1996-01 due to no data
# No data found for 1996-02
# Skipping 1996-02 due to no data
# No data found for 1996-03
# Skipping 1996-03 due to no data
# No data found for 1996-04
# Skipping 1996-04 due to no data
# No data found for 1996-05
# Skipping 1996-05 due to no data
# No data found for 1996-06
# Skipping 1996-06 due to no data
# No data found for 1996-07
# Skipping 1996-07 due to no data
# No data found for 1996-08
# Skipping 1996-08 due to no data
# No data found for 1996-09
# Skipping 1996-09 due to no data
# Base date and time: 1996-10-19 17:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 17:18:11|292.0         |
# |1996-10-19 17:18:12|296.0         |
# |1996-10-19 17:18:13|296.0         |
# |1996-10-19 17:18:14|288.0         |
# |1996-10-19 17:18:15|292.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610191700/199610191700.txt
# Base date and time: 1996-10-19 17:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 18:00:00|320.0         |
# |1996-10-19 18:00:01|328.0         |
# |1996-10-19 18:00:02|328.0         |
# |1996-10-19 18:00:03|340.0         |
# |1996-10-19 18:00:04|340.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610191730/199610191730.txt
# Base date and time: 1996-10-19 18:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 18:00:00|292.0         |
# |1996-10-19 18:00:01|296.0         |
# |1996-10-19 18:00:02|308.0         |
# |1996-10-19 18:00:03|312.0         |
# |1996-10-19 18:00:04|320.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610191800/199610191800.txt
# Base date and time: 1996-10-19 18:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 19:00:00|356.0         |
# |1996-10-19 19:00:01|348.0         |
# |1996-10-19 19:00:02|344.0         |
# |1996-10-19 19:00:03|344.0         |
# |1996-10-19 19:00:04|348.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610191830/199610191830.txt
# Base date and time: 1996-10-19 19:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 19:00:00|392.0         |
# |1996-10-19 19:00:01|400.0         |
# |1996-10-19 19:00:02|408.0         |
# |1996-10-19 19:00:03|412.0         |
# |1996-10-19 19:00:04|416.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610191900/199610191900.txt
# Base date and time: 1996-10-19 19:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 20:00:00|340.0         |
# |1996-10-19 20:00:01|348.0         |
# |1996-10-19 20:00:02|348.0         |
# |1996-10-19 20:00:03|352.0         |
# |1996-10-19 20:00:04|352.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610191930/199610191930.txt
# Base date and time: 1996-10-19 20:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 20:00:00|428.0         |
# |1996-10-19 20:00:01|428.0         |
# |1996-10-19 20:00:02|424.0         |
# |1996-10-19 20:00:03|420.0         |
# |1996-10-19 20:00:04|412.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610192000/199610192000.txt
# Base date and time: 1996-10-19 20:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 21:00:00|376.0         |
# |1996-10-19 21:00:01|380.0         |
# |1996-10-19 21:00:02|380.0         |
# |1996-10-19 21:00:03|376.0         |
# |1996-10-19 21:00:04|372.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610192030/199610192030.txt
# Base date and time: 1996-10-19 21:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 21:00:00|388.0         |
# |1996-10-19 21:00:01|376.0         |
# |1996-10-19 21:00:02|368.0         |
# |1996-10-19 21:00:03|372.0         |
# |1996-10-19 21:00:04|376.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610192100/199610192100.txt
# Base date and time: 1996-10-19 21:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 22:00:00|304.0         |
# |1996-10-19 22:00:01|304.0         |
# |1996-10-19 22:00:02|304.0         |
# |1996-10-19 22:00:03|304.0         |
# |1996-10-19 22:00:04|304.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610192130/199610192130.txt
# Base date and time: 1996-10-19 22:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 22:00:00|296.0         |
# |1996-10-19 22:00:01|300.0         |
# |1996-10-19 22:00:02|292.0         |
# |1996-10-19 22:00:03|296.0         |
# |1996-10-19 22:00:04|296.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610192200/199610192200.txt
# Base date and time: 1996-10-19 22:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 23:00:00|276.0         |
# |1996-10-19 23:00:01|272.0         |
# |1996-10-19 23:00:02|268.0         |
# |1996-10-19 23:00:03|268.0         |
# |1996-10-19 23:00:04|272.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610192230/199610192230.txt
# Base date and time: 1996-10-19 23:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-19 23:00:00|364.0         |
# |1996-10-19 23:00:01|352.0         |
# |1996-10-19 23:00:02|352.0         |
# |1996-10-19 23:00:03|368.0         |
# |1996-10-19 23:00:04|368.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610192300/199610192300.txt
# Base date and time: 1996-10-19 23:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 00:00:00|316.0         |
# |1996-10-20 00:00:01|320.0         |
# |1996-10-20 00:00:02|316.0         |
# |1996-10-20 00:00:03|316.0         |
# |1996-10-20 00:00:04|328.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/19/199610192330/199610192330.txt
# Base date and time: 1996-10-20 00:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 00:00:00|364.0         |
# |1996-10-20 00:00:01|372.0         |
# |1996-10-20 00:00:02|376.0         |
# |1996-10-20 00:00:03|372.0         |
# |1996-10-20 00:00:04|360.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200000/199610200000.txt
# Base date and time: 1996-10-20 00:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 01:00:00|368.0         |
# |1996-10-20 01:00:01|356.0         |
# |1996-10-20 01:00:02|344.0         |
# |1996-10-20 01:00:03|332.0         |
# |1996-10-20 01:00:04|332.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200030/199610200030.txt
# Base date and time: 1996-10-20 01:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 01:00:00|224.0         |
# |1996-10-20 01:00:01|220.0         |
# |1996-10-20 01:00:02|224.0         |
# |1996-10-20 01:00:03|224.0         |
# |1996-10-20 01:00:04|232.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200100/199610200100.txt
# Base date and time: 1996-10-20 01:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 02:00:00|448.0         |
# |1996-10-20 02:00:01|436.0         |
# |1996-10-20 02:00:02|424.0         |
# |1996-10-20 02:00:03|420.0         |
# |1996-10-20 02:00:04|404.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200130/199610200130.txt
# Base date and time: 1996-10-20 02:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 02:00:00|348.0         |
# |1996-10-20 02:00:01|340.0         |
# |1996-10-20 02:00:02|340.0         |
# |1996-10-20 02:00:03|352.0         |
# |1996-10-20 02:00:04|352.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200200/199610200200.txt
# Base date and time: 1996-10-20 02:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 03:00:00|316.0         |
# |1996-10-20 03:00:01|316.0         |
# |1996-10-20 03:00:02|312.0         |
# |1996-10-20 03:00:03|312.0         |
# |1996-10-20 03:00:04|316.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200230/199610200230.txt
# Base date and time: 1996-10-20 03:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 03:00:00|456.0         |
# |1996-10-20 03:00:01|440.0         |
# |1996-10-20 03:00:02|432.0         |
# |1996-10-20 03:00:03|420.0         |
# |1996-10-20 03:00:04|404.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200300/199610200300.txt
# Base date and time: 1996-10-20 03:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 04:00:00|240.0         |
# |1996-10-20 04:00:01|240.0         |
# |1996-10-20 04:00:02|240.0         |
# |1996-10-20 04:00:03|236.0         |
# |1996-10-20 04:00:04|240.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200330/199610200330.txt
# Base date and time: 1996-10-20 04:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 04:00:00|248.0         |
# |1996-10-20 04:00:01|252.0         |
# |1996-10-20 04:00:02|252.0         |
# |1996-10-20 04:00:03|252.0         |
# |1996-10-20 04:00:04|248.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200400/199610200400.txt
# Base date and time: 1996-10-20 04:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 05:00:00|248.0         |
# |1996-10-20 05:00:01|248.0         |
# |1996-10-20 05:00:02|252.0         |
# |1996-10-20 05:00:03|252.0         |
# |1996-10-20 05:00:04|252.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200430/199610200430.txt
# Base date and time: 1996-10-20 05:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 05:00:00|252.0         |
# |1996-10-20 05:00:01|252.0         |
# |1996-10-20 05:00:02|252.0         |
# |1996-10-20 05:00:03|256.0         |
# |1996-10-20 05:00:04|252.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200500/199610200500.txt
# Base date and time: 1996-10-20 05:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 06:00:00|252.0         |
# |1996-10-20 06:00:01|256.0         |
# |1996-10-20 06:00:02|256.0         |
# |1996-10-20 06:00:03|252.0         |
# |1996-10-20 06:00:04|252.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200530/199610200530.txt
# Base date and time: 1996-10-20 06:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 06:00:00|308.0         |
# |1996-10-20 06:00:01|304.0         |
# |1996-10-20 06:00:02|304.0         |
# |1996-10-20 06:00:03|304.0         |
# |1996-10-20 06:00:04|304.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200600/199610200600.txt
# Base date and time: 1996-10-20 06:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 07:00:00|312.0         |
# |1996-10-20 07:00:01|312.0         |
# |1996-10-20 07:00:02|316.0         |
# |1996-10-20 07:00:03|312.0         |
# |1996-10-20 07:00:04|316.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200630/199610200630.txt
# Base date and time: 1996-10-20 07:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 07:00:00|336.0         |
# |1996-10-20 07:00:01|336.0         |
# |1996-10-20 07:00:02|332.0         |
# |1996-10-20 07:00:03|340.0         |
# |1996-10-20 07:00:04|336.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200700/199610200700.txt
# Base date and time: 1996-10-20 07:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 08:00:00|308.0         |
# |1996-10-20 08:00:01|316.0         |
# |1996-10-20 08:00:02|312.0         |
# |1996-10-20 08:00:03|312.0         |
# |1996-10-20 08:00:04|316.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200730/199610200730.txt
# Base date and time: 1996-10-20 08:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 08:00:00|332.0         |
# |1996-10-20 08:00:01|332.0         |
# |1996-10-20 08:00:02|336.0         |
# |1996-10-20 08:00:03|336.0         |
# |1996-10-20 08:00:04|336.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200800/199610200800.txt
# Base date and time: 1996-10-20 08:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 09:00:00|324.0         |
# |1996-10-20 09:00:01|328.0         |
# |1996-10-20 09:00:02|324.0         |
# |1996-10-20 09:00:03|328.0         |
# |1996-10-20 09:00:04|332.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200830/199610200830.txt
# Base date and time: 1996-10-20 09:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 09:00:00|380.0         |
# |1996-10-20 09:00:01|380.0         |
# |1996-10-20 09:00:02|380.0         |
# |1996-10-20 09:00:03|384.0         |
# |1996-10-20 09:00:04|384.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200900/199610200900.txt
# Base date and time: 1996-10-20 09:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 10:00:00|356.0         |
# |1996-10-20 10:00:01|360.0         |
# |1996-10-20 10:00:02|356.0         |
# |1996-10-20 10:00:03|356.0         |
# |1996-10-20 10:00:04|352.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610200930/199610200930.txt
# Base date and time: 1996-10-20 10:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 10:00:00|356.0         |
# |1996-10-20 10:00:01|356.0         |
# |1996-10-20 10:00:02|360.0         |
# |1996-10-20 10:00:03|360.0         |
# |1996-10-20 10:00:04|360.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201000/199610201000.txt
# Base date and time: 1996-10-20 10:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 11:00:00|316.0         |
# |1996-10-20 11:00:01|316.0         |
# |1996-10-20 11:00:02|316.0         |
# |1996-10-20 11:00:03|316.0         |
# |1996-10-20 11:00:04|316.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201030/199610201030.txt
# Base date and time: 1996-10-20 11:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 11:00:00|268.0         |
# |1996-10-20 11:00:01|268.0         |
# |1996-10-20 11:00:02|268.0         |
# |1996-10-20 11:00:03|268.0         |
# |1996-10-20 11:00:04|268.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201100/199610201100.txt
# Base date and time: 1996-10-20 11:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 12:00:00|276.0         |
# |1996-10-20 12:00:01|276.0         |
# |1996-10-20 12:00:02|276.0         |
# |1996-10-20 12:00:03|276.0         |
# |1996-10-20 12:00:04|280.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201130/199610201130.txt
# Base date and time: 1996-10-20 12:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 12:00:00|312.0         |
# |1996-10-20 12:00:01|312.0         |
# |1996-10-20 12:00:02|312.0         |
# |1996-10-20 12:00:03|312.0         |
# |1996-10-20 12:00:04|312.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201200/199610201200.txt
# Base date and time: 1996-10-20 12:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 13:00:00|320.0         |
# |1996-10-20 13:00:01|316.0         |
# |1996-10-20 13:00:02|316.0         |
# |1996-10-20 13:00:03|320.0         |
# |1996-10-20 13:00:04|320.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201230/199610201230.txt
# Base date and time: 1996-10-20 13:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 13:00:00|288.0         |
# |1996-10-20 13:00:01|288.0         |
# |1996-10-20 13:00:02|292.0         |
# |1996-10-20 13:00:03|292.0         |
# |1996-10-20 13:00:04|296.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201300/199610201300.txt
# Base date and time: 1996-10-20 13:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 14:00:00|300.0         |
# |1996-10-20 14:00:01|300.0         |
# |1996-10-20 14:00:02|296.0         |
# |1996-10-20 14:00:03|300.0         |
# |1996-10-20 14:00:04|300.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201330/199610201330.txt
# Base date and time: 1996-10-20 14:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 14:00:00|368.0         |
# |1996-10-20 14:00:01|368.0         |
# |1996-10-20 14:00:02|372.0         |
# |1996-10-20 14:00:03|368.0         |
# |1996-10-20 14:00:04|368.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201400/199610201400.txt
# Base date and time: 1996-10-20 14:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 15:00:00|372.0         |
# |1996-10-20 15:00:01|372.0         |
# |1996-10-20 15:00:02|372.0         |
# |1996-10-20 15:00:03|372.0         |
# |1996-10-20 15:00:04|372.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201430/199610201430.txt
# Base date and time: 1996-10-20 15:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 15:00:00|392.0         |
# |1996-10-20 15:00:01|392.0         |
# |1996-10-20 15:00:02|388.0         |
# |1996-10-20 15:00:03|392.0         |
# |1996-10-20 15:00:04|388.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201500/199610201500.txt
# Base date and time: 1996-10-20 15:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 16:00:00|316.0         |
# |1996-10-20 16:00:01|320.0         |
# |1996-10-20 16:00:02|316.0         |
# |1996-10-20 16:00:03|324.0         |
# |1996-10-20 16:00:04|320.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201530/199610201530.txt
# Base date and time: 1996-10-20 16:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 16:00:00|400.0         |
# |1996-10-20 16:00:01|400.0         |
# |1996-10-20 16:00:02|404.0         |
# |1996-10-20 16:00:03|408.0         |
# |1996-10-20 16:00:04|412.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201600/199610201600.txt
# Base date and time: 1996-10-20 16:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 17:00:00|468.0         |
# |1996-10-20 17:00:01|468.0         |
# |1996-10-20 17:00:02|464.0         |
# |1996-10-20 17:00:03|468.0         |
# |1996-10-20 17:00:04|464.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201630/199610201630.txt
# Base date and time: 1996-10-20 17:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 17:00:00|456.0         |
# |1996-10-20 17:00:01|456.0         |
# |1996-10-20 17:00:02|460.0         |
# |1996-10-20 17:00:03|460.0         |
# |1996-10-20 17:00:04|468.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201700/199610201700.txt
# Base date and time: 1996-10-20 17:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 18:00:00|492.0         |
# |1996-10-20 18:00:01|496.0         |
# |1996-10-20 18:00:02|496.0         |
# |1996-10-20 18:00:03|496.0         |
# |1996-10-20 18:00:04|496.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201730/199610201730.txt
# Base date and time: 1996-10-20 18:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 18:00:00|496.0         |
# |1996-10-20 18:00:01|496.0         |
# |1996-10-20 18:00:02|492.0         |
# |1996-10-20 18:00:03|496.0         |
# |1996-10-20 18:00:04|496.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201800/199610201800.txt
# Base date and time: 1996-10-20 18:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 19:00:00|476.0         |
# |1996-10-20 19:00:01|476.0         |
# |1996-10-20 19:00:02|468.0         |
# |1996-10-20 19:00:03|456.0         |
# |1996-10-20 19:00:04|452.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201830/199610201830.txt
# Base date and time: 1996-10-20 19:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 19:00:00|452.0         |
# |1996-10-20 19:00:01|448.0         |
# |1996-10-20 19:00:02|448.0         |
# |1996-10-20 19:00:03|444.0         |
# |1996-10-20 19:00:04|440.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201900/199610201900.txt
# Base date and time: 1996-10-20 19:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 20:00:00|384.0         |
# |1996-10-20 20:00:01|380.0         |
# |1996-10-20 20:00:02|376.0         |
# |1996-10-20 20:00:03|376.0         |
# |1996-10-20 20:00:04|372.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610201930/199610201930.txt
# Base date and time: 1996-10-20 20:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 20:00:00|368.0         |
# |1996-10-20 20:00:01|368.0         |
# |1996-10-20 20:00:02|368.0         |
# |1996-10-20 20:00:03|372.0         |
# |1996-10-20 20:00:04|376.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610202000/199610202000.txt
# Base date and time: 1996-10-20 20:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 21:00:00|360.0         |
# |1996-10-20 21:00:01|360.0         |
# |1996-10-20 21:00:02|360.0         |
# |1996-10-20 21:00:03|360.0         |
# |1996-10-20 21:00:04|360.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610202030/199610202030.txt
# Base date and time: 1996-10-20 21:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 21:00:00|388.0         |
# |1996-10-20 21:00:01|392.0         |
# |1996-10-20 21:00:02|388.0         |
# |1996-10-20 21:00:03|392.0         |
# |1996-10-20 21:00:04|392.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610202100/199610202100.txt
# Base date and time: 1996-10-20 21:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 22:00:00|360.0         |
# |1996-10-20 22:00:01|360.0         |
# |1996-10-20 22:00:02|364.0         |
# |1996-10-20 22:00:03|360.0         |
# |1996-10-20 22:00:04|360.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610202130/199610202130.txt
# Base date and time: 1996-10-20 22:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 22:00:00|368.0         |
# |1996-10-20 22:00:01|368.0         |
# |1996-10-20 22:00:02|368.0         |
# |1996-10-20 22:00:03|368.0         |
# |1996-10-20 22:00:04|368.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610202200/199610202200.txt
# Base date and time: 1996-10-20 22:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 23:00:00|352.0         |
# |1996-10-20 23:00:01|352.0         |
# |1996-10-20 23:00:02|352.0         |
# |1996-10-20 23:00:03|356.0         |
# |1996-10-20 23:00:04|356.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610202230/199610202230.txt
# Base date and time: 1996-10-20 23:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-20 23:00:00|344.0         |
# |1996-10-20 23:00:01|348.0         |
# |1996-10-20 23:00:02|348.0         |
# |1996-10-20 23:00:03|348.0         |
# |1996-10-20 23:00:04|348.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610202300/199610202300.txt
# Base date and time: 1996-10-20 23:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 00:00:00|404.0         |
# |1996-10-21 00:00:01|396.0         |
# |1996-10-21 00:00:02|400.0         |
# |1996-10-21 00:00:03|396.0         |
# |1996-10-21 00:00:04|396.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/20/199610202330/199610202330.txt
# Base date and time: 1996-10-21 00:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 00:00:00|352.0         |
# |1996-10-21 00:00:01|352.0         |
# |1996-10-21 00:00:02|352.0         |
# |1996-10-21 00:00:03|352.0         |
# |1996-10-21 00:00:04|352.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210000/199610210000.txt
# Base date and time: 1996-10-21 00:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 01:00:00|380.0         |
# |1996-10-21 01:00:01|380.0         |
# |1996-10-21 01:00:02|380.0         |
# |1996-10-21 01:00:03|384.0         |
# |1996-10-21 01:00:04|384.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210030/199610210030.txt
# Base date and time: 1996-10-21 01:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 01:00:00|340.0         |
# |1996-10-21 01:00:01|340.0         |
# |1996-10-21 01:00:02|340.0         |
# |1996-10-21 01:00:03|340.0         |
# |1996-10-21 01:00:04|340.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210100/199610210100.txt
# Base date and time: 1996-10-21 01:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 02:00:00|360.0         |
# |1996-10-21 02:00:01|360.0         |
# |1996-10-21 02:00:02|356.0         |
# |1996-10-21 02:00:03|360.0         |
# |1996-10-21 02:00:04|360.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210130/199610210130.txt
# Base date and time: 1996-10-21 02:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 02:00:00|308.0         |
# |1996-10-21 02:00:01|308.0         |
# |1996-10-21 02:00:02|308.0         |
# |1996-10-21 02:00:03|308.0         |
# |1996-10-21 02:00:04|308.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210200/199610210200.txt
# Base date and time: 1996-10-21 02:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 03:00:00|336.0         |
# |1996-10-21 03:00:01|336.0         |
# |1996-10-21 03:00:02|336.0         |
# |1996-10-21 03:00:03|332.0         |
# |1996-10-21 03:00:04|336.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210230/199610210230.txt
# Base date and time: 1996-10-21 03:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 03:00:00|404.0         |
# |1996-10-21 03:00:01|400.0         |
# |1996-10-21 03:00:02|404.0         |
# |1996-10-21 03:00:03|400.0         |
# |1996-10-21 03:00:04|404.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210300/199610210300.txt
# Base date and time: 1996-10-21 03:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 04:00:00|268.0         |
# |1996-10-21 04:00:01|272.0         |
# |1996-10-21 04:00:02|272.0         |
# |1996-10-21 04:00:03|272.0         |
# |1996-10-21 04:00:04|272.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210330/199610210330.txt
# Base date and time: 1996-10-21 04:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 04:00:00|280.0         |
# |1996-10-21 04:00:01|284.0         |
# |1996-10-21 04:00:02|284.0         |
# |1996-10-21 04:00:03|288.0         |
# |1996-10-21 04:00:04|284.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210400/199610210400.txt
# Base date and time: 1996-10-21 04:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 05:00:00|304.0         |
# |1996-10-21 05:00:01|304.0         |
# |1996-10-21 05:00:02|304.0         |
# |1996-10-21 05:00:03|304.0         |
# |1996-10-21 05:00:04|304.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210430/199610210430.txt
# Base date and time: 1996-10-21 05:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 05:00:00|380.0         |
# |1996-10-21 05:00:01|384.0         |
# |1996-10-21 05:00:02|384.0         |
# |1996-10-21 05:00:03|384.0         |
# |1996-10-21 05:00:04|384.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210500/199610210500.txt
# Base date and time: 1996-10-21 05:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 06:00:00|348.0         |
# |1996-10-21 06:00:01|344.0         |
# |1996-10-21 06:00:02|344.0         |
# |1996-10-21 06:00:03|348.0         |
# |1996-10-21 06:00:04|344.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210530/199610210530.txt
# Base date and time: 1996-10-21 06:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 06:00:00|368.0         |
# |1996-10-21 06:00:01|368.0         |
# |1996-10-21 06:00:02|368.0         |
# |1996-10-21 06:00:03|364.0         |
# |1996-10-21 06:00:04|364.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210600/199610210600.txt
# Base date and time: 1996-10-21 06:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 07:00:00|292.0         |
# |1996-10-21 07:00:01|296.0         |
# |1996-10-21 07:00:02|300.0         |
# |1996-10-21 07:00:03|296.0         |
# |1996-10-21 07:00:04|296.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210630/199610210630.txt
# Base date and time: 1996-10-21 07:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 07:00:00|328.0         |
# |1996-10-21 07:00:01|328.0         |
# |1996-10-21 07:00:02|328.0         |
# |1996-10-21 07:00:03|328.0         |
# |1996-10-21 07:00:04|328.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210700/199610210700.txt
# Base date and time: 1996-10-21 07:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 08:00:00|292.0         |
# |1996-10-21 08:00:01|296.0         |
# |1996-10-21 08:00:02|292.0         |
# |1996-10-21 08:00:03|292.0         |
# |1996-10-21 08:00:04|296.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210730/199610210730.txt
# Base date and time: 1996-10-21 08:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 08:00:00|296.0         |
# |1996-10-21 08:00:01|292.0         |
# |1996-10-21 08:00:02|288.0         |
# |1996-10-21 08:00:03|292.0         |
# |1996-10-21 08:00:04|288.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210800/199610210800.txt
# Base date and time: 1996-10-21 08:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 09:00:00|316.0         |
# |1996-10-21 09:00:01|312.0         |
# |1996-10-21 09:00:02|316.0         |
# |1996-10-21 09:00:03|316.0         |
# |1996-10-21 09:00:04|316.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210830/199610210830.txt
# Base date and time: 1996-10-21 09:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 09:00:00|268.0         |
# |1996-10-21 09:00:01|264.0         |
# |1996-10-21 09:00:02|264.0         |
# |1996-10-21 09:00:03|264.0         |
# |1996-10-21 09:00:04|268.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210900/199610210900.txt
# Base date and time: 1996-10-21 09:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 10:00:00|292.0         |
# |1996-10-21 10:00:01|292.0         |
# |1996-10-21 10:00:02|288.0         |
# |1996-10-21 10:00:03|288.0         |
# |1996-10-21 10:00:04|288.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610210930/199610210930.txt
# Base date and time: 1996-10-21 10:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 10:00:00|268.0         |
# |1996-10-21 10:00:01|268.0         |
# |1996-10-21 10:00:02|268.0         |
# |1996-10-21 10:00:03|268.0         |
# |1996-10-21 10:00:04|268.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610211000/199610211000.txt
# Base date and time: 1996-10-21 10:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 11:00:00|396.0         |
# |1996-10-21 11:00:01|396.0         |
# |1996-10-21 11:00:02|396.0         |
# |1996-10-21 11:00:03|396.0         |
# |1996-10-21 11:00:04|396.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610211030/199610211030.txt
# Base date and time: 1996-10-21 11:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 11:00:00|344.0         |
# |1996-10-21 11:00:01|348.0         |
# |1996-10-21 11:00:02|348.0         |
# |1996-10-21 11:00:03|344.0         |
# |1996-10-21 11:00:04|344.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610211100/199610211100.txt
# Base date and time: 1996-10-21 11:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 12:00:00|332.0         |
# |1996-10-21 12:00:01|332.0         |
# |1996-10-21 12:00:02|332.0         |
# |1996-10-21 12:00:03|332.0         |
# |1996-10-21 12:00:04|328.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610211130/199610211130.txt
# Base date and time: 1996-10-21 12:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 12:00:00|340.0         |
# |1996-10-21 12:00:01|340.0         |
# |1996-10-21 12:00:02|336.0         |
# |1996-10-21 12:00:03|332.0         |
# |1996-10-21 12:00:04|332.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610211200/199610211200.txt
# Base date and time: 1996-10-21 12:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 13:00:00|352.0         |
# |1996-10-21 13:00:01|356.0         |
# |1996-10-21 13:00:02|352.0         |
# |1996-10-21 13:00:03|348.0         |
# |1996-10-21 13:00:04|348.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/10/21/199610211230/199610211230.txt
# Base date and time: 1996-10-21 13:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-10-21 13:00:00|372.0         |
# |1996-10-21 13:00:01|368.0         |
# |1996-10-21 13:00:02|372.0         |
# |1996-10-21 13:00:03|368.0         |
# |1996-10-21 13:00:04|368.0         |
# ...
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-19 22:00:00|288.0         |
# |1996-11-19 22:00:01|284.0         |
# |1996-11-19 22:00:02|280.0         |
# |1996-11-19 22:00:03|276.0         |
# |1996-11-19 22:00:04|284.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/19/199611192130/199611192130.txt
# Base date and time: 1996-11-19 22:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-19 22:00:00|416.0         |
# |1996-11-19 22:00:01|416.0         |
# |1996-11-19 22:00:02|416.0         |
# |1996-11-19 22:00:03|412.0         |
# |1996-11-19 22:00:04|416.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/19/199611192200/199611192200.txt
# Base date and time: 1996-11-19 22:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-19 23:00:00|324.0         |
# |1996-11-19 23:00:01|324.0         |
# |1996-11-19 23:00:02|320.0         |
# |1996-11-19 23:00:03|324.0         |
# |1996-11-19 23:00:04|324.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/19/199611192230/199611192230.txt
# Base date and time: 1996-11-19 23:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-19 23:00:00|320.0         |
# |1996-11-19 23:00:01|320.0         |
# |1996-11-19 23:00:02|320.0         |
# |1996-11-19 23:00:03|328.0         |
# |1996-11-19 23:00:04|324.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/19/199611192300/199611192300.txt
# Base date and time: 1996-11-19 23:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 00:00:00|288.0         |
# |1996-11-20 00:00:01|288.0         |
# |1996-11-20 00:00:02|284.0         |
# |1996-11-20 00:00:03|284.0         |
# |1996-11-20 00:00:04|284.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/19/199611192330/199611192330.txt
# Base date and time: 1996-11-20 00:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 00:00:00|256.0         |
# |1996-11-20 00:00:01|256.0         |
# |1996-11-20 00:00:02|256.0         |
# |1996-11-20 00:00:03|256.0         |
# |1996-11-20 00:00:04|256.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200000/199611200000.txt
# Base date and time: 1996-11-20 00:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 01:00:00|268.0         |
# |1996-11-20 01:00:01|268.0         |
# |1996-11-20 01:00:02|268.0         |
# |1996-11-20 01:00:03|264.0         |
# |1996-11-20 01:00:04|268.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200030/199611200030.txt
# Base date and time: 1996-11-20 01:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 01:00:00|256.0         |
# |1996-11-20 01:00:01|256.0         |
# |1996-11-20 01:00:02|256.0         |
# |1996-11-20 01:00:03|252.0         |
# |1996-11-20 01:00:04|256.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200100/199611200100.txt
# Base date and time: 1996-11-20 01:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 02:00:00|268.0         |
# |1996-11-20 02:00:01|264.0         |
# |1996-11-20 02:00:02|264.0         |
# |1996-11-20 02:00:03|264.0         |
# |1996-11-20 02:00:04|268.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200130/199611200130.txt
# Base date and time: 1996-11-20 02:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 02:00:00|304.0         |
# |1996-11-20 02:00:01|304.0         |
# |1996-11-20 02:00:02|304.0         |
# |1996-11-20 02:00:03|300.0         |
# |1996-11-20 02:00:04|304.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200200/199611200200.txt
# Base date and time: 1996-11-20 02:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 03:00:00|240.0         |
# |1996-11-20 03:00:01|236.0         |
# |1996-11-20 03:00:02|244.0         |
# |1996-11-20 03:00:03|236.0         |
# |1996-11-20 03:00:04|236.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200230/199611200230.txt
# Base date and time: 1996-11-20 03:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 03:00:00|240.0         |
# |1996-11-20 03:00:01|240.0         |
# |1996-11-20 03:00:02|240.0         |
# |1996-11-20 03:00:03|244.0         |
# |1996-11-20 03:00:04|240.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200300/199611200300.txt
# Base date and time: 1996-11-20 03:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 04:00:00|264.0         |
# |1996-11-20 04:00:01|264.0         |
# |1996-11-20 04:00:02|268.0         |
# |1996-11-20 04:00:03|264.0         |
# |1996-11-20 04:00:04|268.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200330/199611200330.txt
# Base date and time: 1996-11-20 04:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 04:00:00|264.0         |
# |1996-11-20 04:00:01|264.0         |
# |1996-11-20 04:00:02|272.0         |
# |1996-11-20 04:00:03|268.0         |
# |1996-11-20 04:00:04|268.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200400/199611200400.txt
# Base date and time: 1996-11-20 04:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 05:00:00|320.0         |
# |1996-11-20 05:00:01|320.0         |
# |1996-11-20 05:00:02|324.0         |
# |1996-11-20 05:00:03|324.0         |
# |1996-11-20 05:00:04|320.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200430/199611200430.txt
# Base date and time: 1996-11-20 05:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 05:00:00|316.0         |
# |1996-11-20 05:00:01|312.0         |
# |1996-11-20 05:00:02|316.0         |
# |1996-11-20 05:00:03|312.0         |
# |1996-11-20 05:00:04|312.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200500/199611200500.txt
# Base date and time: 1996-11-20 05:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 06:00:00|504.0         |
# |1996-11-20 06:00:01|504.0         |
# |1996-11-20 06:00:02|504.0         |
# |1996-11-20 06:00:03|508.0         |
# |1996-11-20 06:00:04|512.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200530/199611200530.txt
# Base date and time: 1996-11-20 06:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 06:00:00|304.0         |
# |1996-11-20 06:00:01|304.0         |
# |1996-11-20 06:00:02|304.0         |
# |1996-11-20 06:00:03|300.0         |
# |1996-11-20 06:00:04|300.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200600/199611200600.txt
# Base date and time: 1996-11-20 06:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 07:00:00|400.0         |
# |1996-11-20 07:00:01|400.0         |
# |1996-11-20 07:00:02|400.0         |
# |1996-11-20 07:00:03|400.0         |
# |1996-11-20 07:00:04|400.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200630/199611200630.txt
# Base date and time: 1996-11-20 07:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 07:00:00|412.0         |
# |1996-11-20 07:00:01|408.0         |
# |1996-11-20 07:00:02|408.0         |
# |1996-11-20 07:00:03|408.0         |
# |1996-11-20 07:00:04|408.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200700/199611200700.txt
# Base date and time: 1996-11-20 07:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 08:00:00|216.0         |
# |1996-11-20 08:00:01|216.0         |
# |1996-11-20 08:00:02|216.0         |
# |1996-11-20 08:00:03|216.0         |
# |1996-11-20 08:00:04|216.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200730/199611200730.txt
# Base date and time: 1996-11-20 08:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 08:00:00|236.0         |
# |1996-11-20 08:00:01|232.0         |
# |1996-11-20 08:00:02|236.0         |
# |1996-11-20 08:00:03|236.0         |
# |1996-11-20 08:00:04|236.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611200800/199611200800.txt
# Base date and time: 1996-11-20 11:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 12:12:50|304.0         |
# |1996-11-20 12:12:51|300.0         |
# |1996-11-20 12:12:52|296.0         |
# |1996-11-20 12:12:53|300.0         |
# |1996-11-20 12:12:54|296.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611201130/199611201130.txt
# Base date and time: 1996-11-20 12:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 12:00:00|316.0         |
# |1996-11-20 12:00:01|316.0         |
# |1996-11-20 12:00:02|320.0         |
# |1996-11-20 12:00:03|320.0         |
# |1996-11-20 12:00:04|316.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611201200/199611201200.txt
# Base date and time: 1996-11-20 12:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 13:00:00|296.0         |
# |1996-11-20 13:00:01|292.0         |
# |1996-11-20 13:00:02|288.0         |
# |1996-11-20 13:00:03|284.0         |
# |1996-11-20 13:00:04|284.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611201230/199611201230.txt
# Base date and time: 1996-11-20 13:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 13:00:00|300.0         |
# |1996-11-20 13:00:01|300.0         |
# |1996-11-20 13:00:02|304.0         |
# |1996-11-20 13:00:03|308.0         |
# |1996-11-20 13:00:04|304.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611201300/199611201300.txt
# Base date and time: 1996-11-20 13:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 14:00:00|436.0         |
# |1996-11-20 14:00:01|440.0         |
# |1996-11-20 14:00:02|440.0         |
# |1996-11-20 14:00:03|444.0         |
# |1996-11-20 14:00:04|444.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611201330/199611201330.txt
# Base date and time: 1996-11-20 14:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 14:00:00|268.0         |
# |1996-11-20 14:00:01|268.0         |
# |1996-11-20 14:00:02|268.0         |
# |1996-11-20 14:00:03|268.0         |
# |1996-11-20 14:00:04|272.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611201400/199611201400.txt
# Base date and time: 1996-11-20 14:30:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 15:00:00|304.0         |
# |1996-11-20 15:00:01|304.0         |
# |1996-11-20 15:00:02|300.0         |
# |1996-11-20 15:00:03|304.0         |
# |1996-11-20 15:00:04|304.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611201430/199611201430.txt
# Base date and time: 1996-11-20 15:00:00
# Processed DataFrame (first 5 rows):
# +-------------------+--------------+
# |DATETIME           |ELECTRIC_FIELD|
# +-------------------+--------------+
# |1996-11-20 15:00:00|288.0         |
# |1996-11-20 15:00:01|288.0         |
# |1996-11-20 15:00:02|284.0         |
# |1996-11-20 15:00:03|288.0         |
# |1996-11-20 15:00:04|284.0         |
# +-------------------+--------------+
# only showing top 5 rows
#
# Completed processing file: data/transformed/field_mill_50hz/1996/11/20/199611201500/199611201500.txt
# Base date and time: 1996-11-20 15:30:00
